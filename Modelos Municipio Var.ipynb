# %%
# !pip install pandas seaborn statsmodels sklearn openpyxl xlrd geopandas pysal ppscore

# %%
# General
import pandas as pd
import os
import scripts
import importlib
import numpy as np
import warnings

# Machine Learnign
## Sklearns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVR
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

## Statmodels
from statsmodels.tools import add_constant
import statsmodels.api as sm

## Others
import ppscore as pps
from scipy.cluster.hierarchy import dendrogram, linkage

# Plot
from matplotlib import pyplot as plt
import seaborn as sns

# Geo
import geopandas as gpd
import libpysal
import splot
import esda
from splot.esda import moran_scatterplot, lisa_cluster
from pysal.model import spreg

# %%
importlib.reload(scripts)
# Out:
# <module 'scripts' from '/Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/scripts.py'>

# %% [markdown]
# ### Carregar Dados

# %%
df_jan = pd.read_csv('dataset/novo/municipio_jan vs 2.csv', sep = ';', decimal = ',', index_col = 0)

df_jan.head()
# Out:
#                   REGIAO  UF MUNICIPIO_DESCRICAO  Capital  IDHM_2010  \
# MUNICIPIO_IBGE
# 1302603            Norte  AM              Manaus        1      0.625
# 2507507         Nordeste  PB         João Pessoa        1      0.697
# 2304400         Nordeste  CE           Fortaleza        1      0.670
# 2927408         Nordeste  BA            Salvador        1      0.753
# 2704302         Nordeste  AL              Maceió        1      0.640
#
#                 Renda_2010  SaldoEmprego_01  Dens_Demográfica  \
# MUNICIPIO_IBGE
# 1302603             762.54            878.0            158.06
# 2507507             627.59             41.0           3421.30
# 2304400             562.53            948.0           7786.52
# 2927408             727.33           1113.0           3859.35
# 2704302             401.42           -427.0           1854.12
#
#                 Perc_EnsinoMedio_2010  Perc_EnsinoSuper_2010  Preco_jan_2020  \
# MUNICIPIO_IBGE
# 1302603                         49.86                  10.97     4611.637209
# 2507507                         49.91                  18.61     4329.077250
# 2304400                         45.93                  13.73     5744.260562
# 2927408                         52.28                  14.59     5037.085869
# 2704302                         41.83                  14.24     4831.409966
#
#                 POPULAÇÃO ESTIMADA  SdoEmpresas_01  Contratacoes2020
# MUNICIPIO_IBGE
# 1302603                    2219580          4904.0         -2.970542
# 2507507                     817511          2702.0          5.858631
# 2304400                    2686612          6393.0          2.347699
# 2927408                    2886698          6872.0          0.678999
# 2704302                    1025360          2205.0          3.382282

# %%
sns.pairplot(df_jan.iloc[:,3:])

plt.show()

# %%
df_dez = pd.read_csv('dataset/novo/municipio_dez vs 2.csv', sep = ';', decimal = ',', index_col = 0)

df_dez.head()
# Out:
#                   REGIAO  UF MUNICIPIO_DESCRICAO  Capital  IDHM_2010  \
# MUNICIPIO_IBGE
# 1302603            Norte  AM              Manaus        1      0.625
# 2507507         Nordeste  PB         João Pessoa        1      0.697
# 2304400         Nordeste  CE           Fortaleza        1      0.670
# 2927408         Nordeste  BA            Salvador        1      0.753
# 2704302         Nordeste  AL              Maceió        1      0.640
#
#                 Renda_2010  SaldoEmprego_12  Dens_Demográfica  \
# MUNICIPIO_IBGE
# 1302603             762.54          -1451.0            158.06
# 2507507             627.59           1553.0           3421.30
# 2304400             562.53           1804.0           7786.52
# 2927408             727.33            523.0           3859.35
# 2704302             401.42            840.0           1854.12
#
#                 casosAcumulado_12  Perc_EnsinoMedio_2010  \
# MUNICIPIO_IBGE
# 1302603                     82218                  49.86
# 2507507                     41879                  49.91
# 2304400                     81893                  45.93
# 2927408                    109906                  52.28
# 2704302                     36320                  41.83
#
#                 Perc_EnsinoSuper_2010  Preco_dez_2020  POPULAÇÃO ESTIMADA  \
# MUNICIPIO_IBGE
# 1302603                         10.97     5046.799519             2219580
# 2507507                         18.61     4515.431694              817511
# 2304400                         13.73     5947.932900             2686612
# 2927408                         14.59     5210.399506             2886698
# 2704302                         14.24     5194.891963             1025360
#
#                 SdoEmpresas_12  Contratacoes2020
# MUNICIPIO_IBGE
# 1302603                23234.0         -2.970542
# 2507507                11219.0          5.858631
# 2304400                29292.0          2.347699
# 2927408                33003.0          0.678999
# 2704302                10293.0          3.382282

# %%
sns.pairplot(df_dez.iloc[:,3:])

plt.show()

# %%
df_var = pd.read_csv('dataset/novo/municipio_var vs 2.csv', sep = ';', decimal = ',', index_col = 0)

df_var.head()
# Out:
#                   REGIAO  UF MUNICIPIO_DESCRICAO  Capital  IDHM_2010  \
# MUNICIPIO_IBGE
# 1302603            Norte  AM              Manaus        1      0.625
# 2507507         Nordeste  PB         João Pessoa        1      0.697
# 2304400         Nordeste  CE           Fortaleza        1      0.670
# 2927408         Nordeste  BA            Salvador        1      0.753
# 2704302         Nordeste  AL              Maceió        1      0.640
#
#                 Renda_2010  Var_SaldoEmprego  Dens_Demográfica  \
# MUNICIPIO_IBGE
# 1302603             762.54           -2329.0            158.06
# 2507507             627.59            1512.0           3421.30
# 2304400             562.53             856.0           7786.52
# 2927408             727.33            -590.0           3859.35
# 2704302             401.42            1267.0           1854.12
#
#                 casosAcumulado_12  Perc_EnsinoMedio_2010  \
# MUNICIPIO_IBGE
# 1302603                     82218                  49.86
# 2507507                     41879                  49.91
# 2304400                     81893                  45.93
# 2927408                    109906                  52.28
# 2704302                     36320                  41.83
#
#                 Perc_EnsinoSuper_2010  Variacao_preco  POPULAÇÃO ESTIMADA  \
# MUNICIPIO_IBGE
# 1302603                         10.97      435.162310             2219580
# 2507507                         18.61      186.354444              817511
# 2304400                         13.73      203.672337             2686612
# 2927408                         14.59      173.313637             2886698
# 2704302                         14.24      363.481996             1025360
#
#                 SdoEmpresas_var  Contratacoes2020
# MUNICIPIO_IBGE
# 1302603                 18330.0         -2.970542
# 2507507                  8517.0          5.858631
# 2304400                 22899.0          2.347699
# 2927408                 26131.0          0.678999
# 2704302                  8088.0          3.382282

# %%
sns.pairplot(df_var.iloc[:,3:])

plt.show()

# %%
df = df_var

# Modificar para variação relativa
# df['Variacao_preco'] = (df_dez['Preco_dez_2020'] / df_jan['Preco_jan_2020']) - 1

# %% [markdown]
# ### Carregas Municpios Espacial

# %%
# muncipios = pd.read_pickle('bases-gdrive/Dados Processados/municipios.pkl')

municipios = gpd.read_file('bases-gdrive/Shapefile/Munic_brasil/munic_brasil.shp', index_col = 0)

municipios.head()
# Out:
#    ID      AREA  GEOCODIGO                  NOME              NOMECAPS  UF  \
# 0   2  76680.43    1300201      Atalaia do Norte      ATALAIA DO NORTE  AM
# 1   1   5474.51    1200336           Mâncio Lima           MANCIO LIMA  AC
# 2  12   8832.70    1300607     Benjamin Constant     BENJAMIN CONSTANT  AM
# 3  23   3236.87    1304062             Tabatinga             TABATINGA  AM
# 4  24  12363.85    1303700  Santo Antônio do Içá  SANTO ANTONIO DO ICA  AM
#
#    CODUF REGIAO           MESORREGIA       MICRORREGI    RM  POP2004  \
# 0     13  Norte  SUDOESTE AMAZONENSE    ALTO SOLIMOES  None    11023
# 1     12  Norte        VALE DO JURUA  CRUZEIRO DO SUL  None    11883
# 2     13  Norte  SUDOESTE AMAZONENSE    ALTO SOLIMOES  None    25542
# 3     13  Norte  SUDOESTE AMAZONENSE    ALTO SOLIMOES  None    42652
# 4     13  Norte  SUDOESTE AMAZONENSE    ALTO SOLIMOES  None    33421
#
#    DENSDEMO                                           geometry
# 0      0.14  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...
# 1      2.17  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...
# 2      2.89  POLYGON ((-70.13532 -4.28746, -70.12815 -4.293...
# 3     13.18  POLYGON ((-69.95428 -4.26597, -69.95329 -4.253...
# 4      2.70  POLYGON ((-69.83709 -3.68623, -69.82498 -3.620...

# %% [markdown]
# ### Juntar Dados

# %%
esp_df = pd.merge(
    left = municipios,
    right = df,
    left_on = 'GEOCODIGO',
    right_index = True,
    how = 'right'
)

print(esp_df.shape)
esp_df.head()
# Out:
# (50, 29)
#        ID      AREA  GEOCODIGO         NOME     NOMECAPS UF_x  CODUF  \
# 949   127  11455.38    1302603       Manaus       MANAUS   AM     13
# 121  5792    214.06    2507507  João Pessoa  JOAO PESSOA   PB     25
# 84   5052    320.12    2304400    Fortaleza    FORTALEZA   CE     23
# 621  5883    319.86    2927408     Salvador     SALVADOR   BA     29
# 146  5581    516.46    2704302       Maceió       MACEIO   AL     27
#
#      REGIAO_x                  MESORREGIA   MICRORREGI  ... Renda_2010  \
# 949     Norte           CENTRO AMAZONENSE       MANAUS  ...     762.54
# 121  Nordeste              MATA PARAIBANA  JOAO PESSOA  ...     627.59
# 84   Nordeste  METROPOLITANA DE FORTALEZA    FORTALEZA  ...     562.53
# 621  Nordeste   METROPOLITANA DE SALVADOR     SALVADOR  ...     727.33
# 146  Nordeste              LESTE ALAGOANO       MACEIO  ...     401.42
#
#      Var_SaldoEmprego  Dens_Demográfica casosAcumulado_12  \
# 949           -2329.0            158.06             82218
# 121            1512.0           3421.30             41879
# 84              856.0           7786.52             81893
# 621            -590.0           3859.35            109906
# 146            1267.0           1854.12             36320
#
#     Perc_EnsinoMedio_2010 Perc_EnsinoSuper_2010 Variacao_preco  \
# 949                 49.86                 10.97     435.162310
# 121                 49.91                 18.61     186.354444
# 84                  45.93                 13.73     203.672337
# 621                 52.28                 14.59     173.313637
# 146                 41.83                 14.24     363.481996
#
#      POPULAÇÃO ESTIMADA  SdoEmpresas_var  Contratacoes2020
# 949             2219580          18330.0         -2.970542
# 121              817511           8517.0          5.858631
# 84              2686612          22899.0          2.347699
# 621             2886698          26131.0          0.678999
# 146             1025360           8088.0          3.382282
#
# [5 rows x 29 columns]

# %%
esp_df.to_file('Shapefiles/Municipio-Var/')

# %%
#  df = df[df['Mun_IBGE'] != 'São Paulo (SP)']

# %% [markdown]
# ### Selecionar dados para modelos

# %%
target = 'Variacao_preco'

x = df.iloc[:,3:].drop([target], axis = 1)

labels = x.columns

y = df[target]

x_y = pd.merge(x, y, left_index=True, right_index=True)

x.head()
# Out:
#                 Capital  IDHM_2010  Renda_2010  Var_SaldoEmprego  \
# MUNICIPIO_IBGE
# 1302603               1      0.625      762.54           -2329.0
# 2507507               1      0.697      627.59            1512.0
# 2304400               1      0.670      562.53             856.0
# 2927408               1      0.753      727.33            -590.0
# 2704302               1      0.640      401.42            1267.0
#
#                 Dens_Demográfica  casosAcumulado_12  Perc_EnsinoMedio_2010  \
# MUNICIPIO_IBGE
# 1302603                   158.06              82218                  49.86
# 2507507                  3421.30              41879                  49.91
# 2304400                  7786.52              81893                  45.93
# 2927408                  3859.35             109906                  52.28
# 2704302                  1854.12              36320                  41.83
#
#                 Perc_EnsinoSuper_2010  POPULAÇÃO ESTIMADA  SdoEmpresas_var  \
# MUNICIPIO_IBGE
# 1302603                         10.97             2219580          18330.0
# 2507507                         18.61              817511           8517.0
# 2304400                         13.73             2686612          22899.0
# 2927408                         14.59             2886698          26131.0
# 2704302                         14.24             1025360           8088.0
#
#                 Contratacoes2020
# MUNICIPIO_IBGE
# 1302603                -2.970542
# 2507507                 5.858631
# 2304400                 2.347699
# 2927408                 0.678999
# 2704302                 3.382282

# %% [markdown]
# ### Correlações

# %%
scripts.corr(x_y, figsize = (20,15))

# %% [markdown]
# ### PPS index

# %%
plt.figure(figsize=(20, 15))

matrix_df = pps.matrix(x_y)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')

sns.heatmap(matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)

plt.show()

# %% [markdown]
# ### Remoção de Variáveis com alta correlação

# %%
# drop_labels = [
#     'SaldoEmprego_12', 'Var_SaldoEmprego', 'casosNovos_03', 'obitosAcumulado_03', 'EmpFechadas_03',
#     'obitosNovos_03', 'Var_CasosAcumulados', 'obitosAcumulado_12', 'Var_EmpFechadas', 'casosAcumulado_12',
#     'EmpFechadas_12', 'obitosNovos_12', 'Perc_EnsinoSuper_2010' #'Var_CasosAcumulados.1', #'Capital',
#     #'casosNovos_12'
# ]


# x = x.drop(axis = 1, 
#            labels = drop_labels
#           )

# labels = x.columns

# y = df['Variacao_preco']

# x_y = pd.merge(x, y, left_index=True, right_index=True)


# x.head()

# %%
scripts.corr(x_y, figsize = (20,15))

# %%
x.skew()
# Out:
# Capital                  0.795820
# IDHM_2010               -0.422680
# Renda_2010               2.082535
# Var_SaldoEmprego        -4.763648
# Dens_Demográfica         1.664844
# casosAcumulado_12        3.870558
# Perc_EnsinoMedio_2010    0.062961
# Perc_EnsinoSuper_2010    0.545408
# Variacao_preco           1.116451
# POPULAÇÃO ESTIMADA       4.394946
# SdoEmpresas_var          4.619060
# dtype: float64

# %%
x['casosNovos_12'] = x['casosNovos_12'].apply(lambda n: max(0,n))

# %%
for s, i in zip(x.skew(), x.columns):
    if s > 2.5:
        x[i] = np.log(x[i] + 1)
# Out:
# casosNovos_12
# Var_CasosAcumulados.1

# %%
x.skew()
# Out:
# Capital                  0.795820
# IDHM_2010               -0.422680
# Renda_2010               2.082535
# SaldoEmprego_01          4.131116
# Dens_Demográfica         1.664844
# Perc_EnsinoMedio_2010    0.062961
# Perc_EnsinoSuper_2010    0.545408
# dtype: float64

# %%
x.kurtosis()
# Out:
# Capital                  -1.425366
# IDHM_2010                -0.117557
# Renda_2010                6.737616
# SaldoEmprego_01          27.726432
# Dens_Demográfica          2.525127
# Perc_EnsinoMedio_2010     0.298522
# Perc_EnsinoSuper_2010    -0.282895
# dtype: float64

# %% [markdown]
# ### Realizar Normalização

# %%
x_norm = pd.DataFrame(StandardScaler().fit_transform(x), columns = x.columns, index = x.index)

x_y_norm = pd.DataFrame(StandardScaler().fit_transform(x_y), columns = x_y.columns, index = x_y.index)

# %% [markdown]
# ### Regressão Linear

# %%
lm = sm.OLS(endog = y, exog = add_constant(x_norm))

r = lm.fit()

sns.regplot(x = r.predict(add_constant(x_norm)), y = y)

plt.show()

r.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Variacao_preco   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     1.888
# Date:                Sat, 27 Mar 2021   Prob (F-statistic):             0.0769
# Time:                        14:55:45   Log-Likelihood:                -320.61
# No. Observations:                  50   AIC:                             663.2
# Df Residuals:                      39   BIC:                             684.3
# Df Model:                          10
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   199.7194     23.605      8.461      0.000     151.974     247.465
# Capital                  70.3341     34.864      2.017      0.051      -0.184     140.852
# IDHM_2010                 6.9218     28.055      0.247      0.806     -49.824      63.667
# Renda_2010               24.1360     30.352      0.795      0.431     -37.256      85.528
# Var_SaldoEmprego        -23.1732     34.416     -0.673      0.505     -92.785      46.439
# Dens_Demográfica         15.6632     27.710      0.565      0.575     -40.385      71.712
# casosAcumulado_12       196.8384     81.007      2.430      0.020      32.987     360.690
# Perc_EnsinoMedio_2010     8.8444     67.874      0.130      0.897    -128.444     146.133
# Perc_EnsinoSuper_2010   -13.7745     69.209     -0.199      0.843    -153.762     126.213
# POPULAÇÃO ESTIMADA     -628.5560    318.669     -1.972      0.056   -1273.125      16.013
# SdoEmpresas_var         413.2745    287.488      1.438      0.159    -168.224     994.773
# ==============================================================================
# Omnibus:                       35.377   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.095
# Skew:                           1.814   Prob(JB):                     2.27e-26
# Kurtosis:                       9.597   Cond. No.                         36.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Stepwise Critério AIC

# %%
drop, aic_remaing, labels_remaining = scripts.iterate_aic(x_norm, y)

drop
# Out:
# ['casosAcumulado_12', 'Capital']

# %% [markdown]
# #### Cross Validation

# %%
pred = scripts.out_of_fold_pred(x_norm.values, y.values, LinearRegression(), folds = 10)

m = scripts.get_metrics(prediction = pred, actual = y.values)
# Out:
# Results
# MSE: 49053.166
# RMSE: 221.479
# MAE: 166.455
# R2: -0.521

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components = 2)

pca_coord = pca.fit_transform(x_y_norm)

# %% [markdown]
# ### KMeans

# %%
kmeans = KMeans(n_clusters = 2).fit_transform(x_y_norm)

sns.scatterplot(pca_coord[:,0], pca_coord[:,1], hue = kmeans.argmax(axis = 1), )
# Out:
# /Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/venv-gv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pd.DataFrame({'Cidade': df.MUNICIPIO_DESCRICAO, 'Cluster': kmeans.argmax(axis = 1)}).sort_values(by = 'Cluster')
# Out:
#                                      Cidade  Cluster
# MUNICIPIO_IBGE
# 3550308              São Paulo (território)        0
# 1302603                              Manaus        1
# 3541000                        Praia Grande        1
# 3548708               São Bernardo do Campo        1
# 4106902                            Curitiba        1
# 3548500                              Santos        1
# 4318705                        São Leopoldo        1
# 4205407                       Florianópolis        1
# 4216602                            São José        1
# 4113700                            Londrina        1
# 4202008                  Balneário Camboriú        1
# 3505708                             Barueri        1
# 4304606                              Canoas        1
# 3551009                         São Vicente        1
# 3518800                           Guarulhos        1
# 4208302                             Itapema        1
# 4202404                            Blumenau        1
# 4209102                           Joinville        1
# 4316907                         Santa Maria        1
# 4313409                       Novo Hamburgo        1
# 5300108                            Brasília        1
# 4314407                             Pelotas        1
# 4314902                        Porto Alegre        1
# 4305108                       Caxias do Sul        1
# 3548807                  São Caetano do Sul        1
# 3534401                              Osasco        1
# 3549805               São José do Rio Preto        1
# 2507507                         João Pessoa        1
# 2304400                           Fortaleza        1
# 2927408                            Salvador        1
# 2704302                              Maceió        1
# 2607901             Jaboatão dos Guararapes        1
# 3118601                            Contagem        1
# 3106200                      Belo Horizonte        1
# 3106705                               Betim        1
# 2611606                              Recife        1
# 3205200                          Vila Velha        1
# 3303302                             Niterói        1
# 3509502                            Campinas        1
# 3205309                             Vitória        1
# 3513801                             Diadema        1
# 3543402                      Ribeirão Preto        1
# 3518701                             Guarujá        1
# 4125506                São José dos Pinhais        1
# 3547809                         Santo André        1
# 3549904                 São José dos Campos        1
# 4208203                              Itajaí        1
# 3304557         Rio de Janeiro (território)        1
# 5002704                        Campo Grande        1
# 5208707                             Goiânia        1

# %% [markdown]
# ##### Outlier

# %%
df[pca_coord[:,0] > 5]
# Out:
#                  REGIAO  UF     MUNICIPIO_DESCRICAO  Capital  IDHM_2010  \
# MUNICIPIO_IBGE
# 3550308         Sudeste  SP  São Paulo (território)        1      0.692
#
#                 Renda_2010  Var_SaldoEmprego  Dens_Demográfica  \
# MUNICIPIO_IBGE
# 3550308             710.04          -38414.0           7387.69
#
#                 casosAcumulado_12  Perc_EnsinoMedio_2010  \
# MUNICIPIO_IBGE
# 3550308                    401718                  47.88
#
#                 Perc_EnsinoSuper_2010  Variacao_preco  POPULAÇÃO ESTIMADA  \
# MUNICIPIO_IBGE
# 3550308                         20.63       310.27217            12325232
#
#                 SdoEmpresas_var  Contratacoes2020
# MUNICIPIO_IBGE
# 3550308                141353.0         -3.284015

# %% [markdown]
# Removendo Outliers

# %%
slicer = pca_coord[:,0] < 5

pca = PCA(n_components = 2)

pca_coord_new = pca.fit_transform(x_y_norm.values[slicer])

kmeans_new = KMeans(n_clusters = 2).fit_transform(x_y_norm.values[slicer])

sns.scatterplot(pca_coord_new[:,0], pca_coord_new[:,1], hue = kmeans_new.argmax(axis = 1), )

plt.show()

pd.DataFrame({'Cidade': df.MUNICIPIO_DESCRICAO[slicer], 'Cluster': kmeans_new.argmax(axis = 1)}).sort_values(by = 'Cluster')
# Out:
# /Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/venv-gv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#                                      Cidade  Cluster
# MUNICIPIO_IBGE
# 1302603                              Manaus        0
# 4314902                        Porto Alegre        0
# 5300108                            Brasília        0
# 4205407                       Florianópolis        0
# 3548500                              Santos        0
# 4106902                            Curitiba        0
# 5002704                        Campo Grande        0
# 3304557         Rio de Janeiro (território)        0
# 3205309                             Vitória        0
# 3303302                             Niterói        0
# 3548807                  São Caetano do Sul        0
# 2611606                              Recife        0
# 2507507                         João Pessoa        0
# 2304400                           Fortaleza        0
# 2927408                            Salvador        0
# 3106200                      Belo Horizonte        0
# 2704302                              Maceió        0
# 5208707                             Goiânia        0
# 3509502                            Campinas        1
# 4314407                             Pelotas        1
# 3106705                               Betim        1
# 4313409                       Novo Hamburgo        1
# 4316907                         Santa Maria        1
# 4209102                           Joinville        1
# 4202404                            Blumenau        1
# 4208302                             Itapema        1
# 3518800                           Guarulhos        1
# 3551009                         São Vicente        1
# 4305108                       Caxias do Sul        1
# 4304606                              Canoas        1
# 4202008                  Balneário Camboriú        1
# 4113700                            Londrina        1
# 4125506                São José dos Pinhais        1
# 3513801                             Diadema        1
# 4318705                        São Leopoldo        1
# 3205200                          Vila Velha        1
# 2607901             Jaboatão dos Guararapes        1
# 3548708               São Bernardo do Campo        1
# 3541000                        Praia Grande        1
# 3505708                             Barueri        1
# 3118601                            Contagem        1
# 3534401                              Osasco        1
# 3549805               São José do Rio Preto        1
# 3543402                      Ribeirão Preto        1
# 4208203                              Itajaí        1
# 3549904                 São José dos Campos        1
# 3547809                         Santo André        1
# 3518701                             Guarujá        1
# 4216602                            São José        1

# %% [markdown]
# ### Cluster Dendograma

# %%
linked = linkage(x_y_norm.values, 'ward')

plt.figure(figsize=(20, 15))
dendrogram(
            linked,
            orientation='right',
            labels=df.MUNICIPIO_DESCRICAO.values,
            distance_sort='descending',
            show_leaf_counts=False
          )
plt.show()

# %% [markdown]
# ### Regressão Espacial

# %%
ax = esp_df.plot(
    column = target,
    figsize = (10,10),
    legend = True,
    legend_kwds = {'label': target, 'orientation': "horizontal"},
)

ax.set_title(target)

ax.set_axis_off()

# %%
esp_df.shape
# Out:
# (50, 29)

# %%
# w = libpysal.weights.Queen.from_dataframe(df, )
# w = libpysal.weights.Voronoi.from_dataframe(df.centroid, )

w = libpysal.weights.DistanceBand.from_dataframe(esp_df, 3)

# TODO método queen com base na distância ou método

w.transform = 'r'
# Out:
# ('WARNING: ', 949, ' is an island (no neighbors)')
# ('WARNING: ', 84, ' is an island (no neighbors)')
# ('WARNING: ', 621, ' is an island (no neighbors)')
# ('WARNING: ', 1902, ' is an island (no neighbors)')
# /Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/venv-gv/lib/python3.9/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 10 disconnected components.
#  There are 4 islands with ids: 949, 84, 621, 1902.
#   warnings.warn(message)

# %%
ax = esp_df.plot(edgecolor='grey', facecolor='w',figsize=(10,10))

f, ax = w.plot(esp_df, ax=ax,
        edge_kws=dict(color='r', linestyle=':', linewidth=1),
        node_kws=dict(marker=''),
              )

ax.set_axis_off()

# %%
moran_I = {}
moran = {}
moran_local = {}

for i in x_y_norm.columns:
    
    moran[i] = esda.Moran(x_y_norm[i].values, w)
#     moran_local[i] = esda.moran.Moran_Local(x_y_norm[i].values, w)
    moran_I[i] = moran[i].I

# %%
# Colocar o preco

(pd.Series(moran_I)
     .rename('Moran I')
     .sort_values(ascending = False)
     .to_frame()
)
# Out:
#                         Moran I
# Variacao_preco         0.250883
# Capital                0.119664
# Dens_Demográfica       0.112315
# Perc_EnsinoMedio_2010  0.100335
# casosAcumulado_12      0.030393
# Perc_EnsinoSuper_2010  0.028926
# Var_SaldoEmprego       0.015364
# IDHM_2010             -0.011437
# POPULAÇÃO ESTIMADA    -0.038212
# Renda_2010            -0.038490
# SdoEmpresas_var       -0.040955

# %%
n = 4

for i in sorted(moran_I.items(), key=lambda x: x[1], reverse=True)[:n]:
    print(i[0])
    moran_scatterplot(moran[i[0]], aspect_equal=True)
    plt.show()
# Out:
# Variacao_preco
# Capital
# Dens_Demográfica
# Perc_EnsinoMedio_2010

# %%
r = spreg.OLS(
        x = x_norm.values, name_x = list(labels),
        y = y.values, 
        w = w,
    )

print(r.summary)

sns.regplot(x = r.predy, y = y)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :     dep_var                Number of Observations:          50
# Mean dependent var  :    199.7194                Number of Variables   :          11
# S.D. dependent var  :    181.4027                Degrees of Freedom    :          39
# R-squared           :      0.3261
# Adjusted R-squared  :      0.1534
# Sum squared residual: 1086542.962                F-statistic           :      1.8876
# Sigma-square        :   27860.076                Prob(F-statistic)     :     0.07694
# S.E. of regression  :     166.913                Log likelihood        :    -320.609
# Sigma-square ML     :   21730.859                Akaike info criterion :     663.218
# S.E of regression ML:    147.4139                Schwarz criterion     :     684.251
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT     199.7194199      23.6051164       8.4608530       0.0000000
#              Capital      70.3341145      34.8636315       2.0174064       0.0505726
#            IDHM_2010       6.9218157      28.0545393       0.2467271       0.8064135
#           Renda_2010      24.1360294      30.3516025       0.7952143       0.4313021
#     Var_SaldoEmprego     -23.1731909      34.4155867      -0.6733342       0.5047056
#     Dens_Demográfica      15.6632260      27.7098616       0.5652582       0.5751358
#    casosAcumulado_12     196.8384074      81.0066996       2.4299028       0.0198071
# Perc_EnsinoMedio_2010       8.8444119      67.8742832       0.1303058       0.8969943
# Perc_EnsinoSuper_2010     -13.7744863      69.2087082      -0.1990282       0.8432747
#   POPULAÇÃO ESTIMADA    -628.5559901     318.6688521      -1.9724425       0.0556792
#      SdoEmpresas_var     413.2745321     287.4877079       1.4375381       0.1585408
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           36.240
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2         118.095           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               10          10.909           0.3647
# Koenker-Bassett test             10           2.538           0.9903
# ================================ END OF REPORT =====================================
# <AxesSubplot:ylabel='Variacao_preco'>

# %%
spatial_regression = spreg.GM_Lag(
        x = x_norm.values, name_x = list(labels),
        y = y.values, name_y = 'preco',
        w = w,
    
        
    )

print(
    spatial_regression.summary
)

sns.regplot(x = spatial_regression.predy, y = y)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :       preco                Number of Observations:          50
# Mean dependent var  :    199.7194                Number of Variables   :          12
# S.D. dependent var  :    181.4027                Degrees of Freedom    :          38
# Pseudo R-squared    :      0.3353
# Spatial Pseudo R-squared:  0.2361
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT     121.3915583      44.5441192       2.7251983       0.0064263
#              Capital      68.1963828      30.6377262       2.2258957       0.0260212
#            IDHM_2010      -1.5259299      25.0029920      -0.0610299       0.9513354
#           Renda_2010      22.7102035      26.6658159       0.8516598       0.3944029
#     Var_SaldoEmprego     -12.6740697      30.6838469      -0.4130535       0.6795674
#     Dens_Demográfica      21.5447733      24.5154648       0.8788238       0.3794968
#    casosAcumulado_12     169.2204645      72.4891876       2.3344235       0.0195736
# Perc_EnsinoMedio_2010     -17.7931206      61.0995573      -0.2912152       0.7708867
# Perc_EnsinoSuper_2010       9.3430827      61.8860123       0.1509724       0.8799975
#   POPULAÇÃO ESTIMADA    -280.0761903     330.2937363      -0.8479609       0.3964597
#      SdoEmpresas_var     104.6380745     296.4495092       0.3529710       0.7241102
#              W_preco       0.4242255       0.2135315       1.9867114       0.0469544
# ------------------------------------------------------------------------------------
# Instrumented: W_preco
# Instruments: W_Capital, W_Dens_Demográfica, W_IDHM_2010, W_POPULAÇÃO
#              ESTIMADA, W_Perc_EnsinoMedio_2010, W_Perc_EnsinoSuper_2010,
#              W_Renda_2010, W_SdoEmpresas_var, W_Var_SaldoEmprego,
#              W_casosAcumulado_12
# ================================ END OF REPORT =====================================
# <AxesSubplot:ylabel='Variacao_preco'>

# %% [markdown]
# ### Random Forests

# %%
rf = RandomForestRegressor(n_estimators = 200)

rf.fit(y = y, X = x_norm)
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
pd.Series(rf.feature_importances_, index = labels).sort_values().plot.barh(figsize = (10,10))

plt.show()

# %%
sns.regplot(x = rf.predict(x_norm), y = y)

plt.show()

# %%
pred = scripts.out_of_fold_pred(x_norm.values, y.values, RandomForestRegressor(n_estimators = 50), folds = 10)

m = scripts.get_metrics(prediction = pred, actual = y.values)
# Out:
# Results
# MSE: 29190.325
# RMSE: 170.852
# MAE: 131.971
# R2: 0.095

# %% [markdown]
# #### Recursive Feature Eliminations

# %%
selector_rf = RFE(rf, n_features_to_select=.5, step=1)

selector_rf = selector_rf.fit(x_norm.values, y.values)

print('Best Features')
pd.Series(selector_rf.ranking_, index = labels).sort_values()
# Out:
# Best Features
# Var_SaldoEmprego         1
# casosAcumulado_12        1
# Perc_EnsinoMedio_2010    1
# Perc_EnsinoSuper_2010    1
# POPULAÇÃO ESTIMADA       1
# IDHM_2010                2
# Renda_2010               3
# SdoEmpresas_var          4
# Dens_Demográfica         5
# Capital                  6
# dtype: int64

# %% [markdown]
# ### Linear Support Vector Regression

# %%
svr = SVR(kernel = 'linear')

svr = svr.fit(y = y, X = x_norm)

# %%
sns.regplot(x = svr.predict(x_norm), y = y)

plt.show()

# %%
pred = scripts.out_of_fold_pred(x_norm.values, y.values, svr, folds = 10)

m = scripts.get_metrics(prediction = pred, actual = y.values)
# Out:
# Results
# MSE: 32398.084
# RMSE: 179.995
# MAE: 127.872
# R2: -0.005

# %%
selector_svr = RFE(SVR(kernel='linear'), n_features_to_select=.5, step=1)

selector_svr = selector_svr.fit(x_norm.values, y.values)

print('Best Features')
pd.Series(selector_svr.ranking_, index = labels).sort_values()
# Out:
# Best Features
# Capital                  1
# Var_SaldoEmprego         1
# Dens_Demográfica         1
# casosAcumulado_12        1
# Perc_EnsinoMedio_2010    1
# Perc_EnsinoSuper_2010    2
# IDHM_2010                3
# SdoEmpresas_var          4
# Renda_2010               5
# POPULAÇÃO ESTIMADA       6
# dtype: int64

# %%
pd.DataFrame(
    {
    'RF Feature Importance': np.argsort(-rf.feature_importances_),
    'RF RFE': selector_rf.ranking_,
    'SVR RFE': selector_svr.ranking_
},
    index = labels
)
# Out:
#                        RF Feature Importance  RF RFE  SVR RFE
# Capital                                    8       6        1
# IDHM_2010                                  3       2        3
# Renda_2010                                 5       3        5
# Var_SaldoEmprego                           6       1        1
# Dens_Demográfica                           7       5        1
# casosAcumulado_12                          9       1        1
# Perc_EnsinoMedio_2010                      2       1        1
# Perc_EnsinoSuper_2010                      1       1        2
# POPULAÇÃO ESTIMADA                         4       1        6
# SdoEmpresas_var                            0       4        4
