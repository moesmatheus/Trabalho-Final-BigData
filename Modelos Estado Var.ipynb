# %%
# !pip install pandas seaborn statsmodels sklearn openpyxl xlrd geopandas pysal ppscore

# %%
# General
import pandas as pd
import os
import scripts
import importlib
import numpy as np
import warnings

# Machine Learnign
## Sklearns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVR
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

## Statmodels
from statsmodels.tools import add_constant
import statsmodels.api as sm

## Others
import ppscore as pps
from scipy.cluster.hierarchy import dendrogram, linkage

# Plot
from matplotlib import pyplot as plt
import seaborn as sns

# Geo
import geopandas as gpd
import libpysal
import splot
import esda
from splot.esda import moran_scatterplot, lisa_cluster
from pysal.model import spreg

# %%
importlib.reload(scripts)
# Out:
# <module 'scripts' from '/Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/scripts.py'>

# %%
sns.set_theme()

# %%
import json

variables = json.load(open('variables.json', 'r'))

variables_sel = variables['est_var']

# %% [markdown]
# ### Carregar Dados

# %%
df_jan = pd.read_csv('dataset/novo/UF_mercado_imobiliario_jan vs 2.csv', sep = ';', decimal = ',', index_col = 0)

df_jan.head()
# Out:
#        UF             Nome_UF  Densidade_populacional_projetada  IDHM 2010  \
# CD_UF
# 53     DF    Distrito Federal                        530.335628      0.824
# 52     GO               Goiás                         20.907243      0.735
# 51     MT         Mato Grosso                          3.904110      0.725
# 50     MS  Mato Grosso do Sul                          7.866190      0.729
# 25     PB             Paraíba                         71.533102      0.658
#
#        Renda per capita 2010  SaldoEmprego_01  Valor_compra_01  \
# CD_UF
# 53                   1715.11           1457.0         240000.0
# 52                    810.97           8081.0         180000.0
# 51                    762.52           9696.0         175000.0
# 50                    799.34           1854.0         165000.0
# 25                    474.94          -2527.0         158540.5
#
#        Valor_contratado_01  Taxa_prop_media_01  Area_privativa_01  \
# CD_UF
# 53            2.313967e+08            8.041858              61.24
# 52            3.114260e+08            7.754394              82.62
# 51            1.565940e+08            7.755467              70.00
# 50            1.222186e+08            7.601646              68.32
# 25            9.884272e+07            7.413085              61.00
#
#        População_estimada  SDO_emprego pela pop_estim  \
# CD_UF
# 53                3055149                    0.000477
# 52                7113540                    0.001136
# 51                3526220                    0.002750
# 50                2809394                    0.000660
# 25                4039277                   -0.000626
#
#        Val_compr pela pop_estim  Val_contr pela pop_estim  SdoEmpresas_01
# CD_UF
# 53                     0.078556                 75.739903          8728.0
# 52                     0.025304                 43.779325         17600.0
# 51                     0.049628                 44.408469          8882.0
# 50                     0.058732                 43.503548          6765.0
# 25                     0.039250                 24.470400          6561.0

# %%
sns.pairplot(df_jan.iloc[:,2:])

plt.show()

# %%
df_dez = pd.read_csv('dataset/novo/UF_mercado_imobiliario_dez vs 2.csv', sep = ';', decimal = ',', index_col = 0)

df_dez.head()
# Out:
#        UF             Nome_UF  Densidade_populacional_projetada  IDHM 2010  \
# CD_UF
# 53     DF    Distrito Federal                        530.335628      0.824
# 52     GO               Goiás                         20.907243      0.735
# 51     MT         Mato Grosso                          3.904110      0.725
# 50     MS  Mato Grosso do Sul                          7.866190      0.729
# 25     PB             Paraíba                         71.533102      0.658
#
#        Renda per capita 2010  SaldoEmprego_12  casosAcumulado_12  \
# CD_UF
# 53                   1715.11          -1023.0             251701
# 52                    810.97          -1208.0             308868
# 51                    762.52          -4203.0             179427
# 50                    799.34          -2466.0             133761
# 25                    474.94           1185.0             166484
#
#        Valor_compra_12  Valor_contratado_12  Taxa_prop_media_12  \
# CD_UF
# 53           239597.96         6.314860e+08            7.639863
# 52           150000.00         6.799661e+08            7.355904
# 51           190000.00         3.166171e+08            7.411909
# 50           160000.00         2.459794e+08            7.545629
# 25           130000.00         2.010239e+08            6.682909
#
#        Area_privativa_12  População_estimada  SDO_emprego pela pop_estim  \
# CD_UF
# 53                 59.85             3055149                   -0.000335
# 52                 76.12             7113540                   -0.000170
# 51                 69.22             3526220                   -0.001192
# 50                 60.54             2809394                   -0.000878
# 25                 52.65             4039277                    0.000293
#
#        Val_compr pela pop_estim  Val_contr pela pop_estim  SdoEmpresas_12
# CD_UF
# 53                     0.078424                206.695655         38649.0
# 52                     0.021087                 95.587583         77671.0
# 51                     0.053882                 89.789373         39731.0
# 50                     0.056952                 87.556024         30206.0
# 25                     0.032184                 49.767302         27561.0

# %%
sns.pairplot(df_dez.iloc[:,2:])

plt.show()

# %%
df_var = pd.read_csv('dataset/novo/UF_mercado_imobiliario_var vs 2.csv', sep = ';', decimal = ',', index_col = 0)

df_var.head()
# Out:
#        UF             Nome_UF  Densidade_populacional_projetada  IDHM 2010  \
# CD_UF
# 53     DF    Distrito Federal                        530.335628      0.824
# 52     GO               Goiás                         20.907243      0.735
# 51     MT         Mato Grosso                          3.904110      0.725
# 50     MS  Mato Grosso do Sul                          7.866190      0.729
# 25     PB             Paraíba                         71.533102      0.658
#
#        Renda per capita 2010  SaldoEmprego_var  casosAcumulado_12  \
# CD_UF
# 53                   1715.11           -2480.0             251701
# 52                    810.97           -9289.0             308868
# 51                    762.52          -13899.0             179427
# 50                    799.34           -4320.0             133761
# 25                    474.94            3712.0             166484
#
#        Valor_compra_var  Valor_contratado_var  Taxa_prop_media_var  \
# CD_UF
# 53              -402.04          4.000893e+08            -0.401995
# 52            -30000.00          3.685401e+08            -0.398489
# 51             15000.00          1.600231e+08            -0.343558
# 50             -5000.00          1.237608e+08            -0.056017
# 25            -28540.50          1.021812e+08            -0.730176
#
#        Area_privativa_var  População_estimada  SDO_emprego pela pop_estim  \
# CD_UF
# 53                  -1.39             3055149                   -0.000812
# 52                  -6.50             7113540                   -0.001306
# 51                  -0.78             3526220                   -0.003942
# 50                  -7.78             2809394                   -0.001538
# 25                  -8.35             4039277                    0.000919
#
#        Val_compr pela pop_estim  Val_contr pela pop_estim  SdoEmpresas_var
# CD_UF
# 53                    -0.000132                130.955752          29921.0
# 52                    -0.004217                 51.808258          60071.0
# 51                     0.004254                 45.380904          30849.0
# 50                    -0.001780                 44.052476          23441.0
# 25                    -0.007066                 25.296902          21000.0

# %%
sns.pairplot(df_var.iloc[:,3:])

plt.show()

# %%
df = df_var


df.head()
# Out:
#        UF             Nome_UF  Densidade_populacional_projetada  IDHM 2010  \
# CD_UF
# 53     DF    Distrito Federal                        530.335628      0.824
# 52     GO               Goiás                         20.907243      0.735
# 51     MT         Mato Grosso                          3.904110      0.725
# 50     MS  Mato Grosso do Sul                          7.866190      0.729
# 25     PB             Paraíba                         71.533102      0.658
#
#        Renda per capita 2010  SaldoEmprego_var  casosAcumulado_12  \
# CD_UF
# 53                   1715.11           -2480.0             251701
# 52                    810.97           -9289.0             308868
# 51                    762.52          -13899.0             179427
# 50                    799.34           -4320.0             133761
# 25                    474.94            3712.0             166484
#
#        Valor_compra_var  Valor_contratado_var  Taxa_prop_media_var  \
# CD_UF
# 53              -402.04          4.000893e+08            -0.401995
# 52            -30000.00          3.685401e+08            -0.398489
# 51             15000.00          1.600231e+08            -0.343558
# 50             -5000.00          1.237608e+08            -0.056017
# 25            -28540.50          1.021812e+08            -0.730176
#
#        Area_privativa_var  População_estimada  SDO_emprego pela pop_estim  \
# CD_UF
# 53                  -1.39             3055149                   -0.000812
# 52                  -6.50             7113540                   -0.001306
# 51                  -0.78             3526220                   -0.003942
# 50                  -7.78             2809394                   -0.001538
# 25                  -8.35             4039277                    0.000919
#
#        Val_compr pela pop_estim  Val_contr pela pop_estim  SdoEmpresas_var
# CD_UF
# 53                    -0.000132                130.955752          29921.0
# 52                    -0.004217                 51.808258          60071.0
# 51                     0.004254                 45.380904          30849.0
# 50                    -0.001780                 44.052476          23441.0
# 25                    -0.007066                 25.296902          21000.0

# %% [markdown]
# ### Carregas Estados Espacial

# %%
estados = gpd.read_file('BR_UF_2020/BR_UF_2020.shp')

estados.head()
# Out:
#   CD_UF     NM_UF SIGLA_UF NM_REGIAO  \
# 0    11  Rondônia       RO     Norte
# 1    12      Acre       AC     Norte
# 2    13  Amazonas       AM     Norte
# 3    14   Roraima       RR     Norte
# 4    15      Pará       PA     Norte
#
#                                             geometry
# 0  POLYGON ((-65.38150 -10.42907, -65.38013 -10.4...
# 1  POLYGON ((-71.07772 -9.82774, -71.07817 -9.828...
# 2  POLYGON ((-69.83766 -3.68659, -69.82555 -3.620...
# 3  POLYGON ((-63.96008 2.47313, -63.96041 2.47416...
# 4  MULTIPOLYGON (((-51.43248 -0.47334, -51.42949 ...

# %% [markdown]
# ### Juntar Dados

# %%
esp_df = pd.merge(
    left = estados,
    right = df,
    left_on = 'SIGLA_UF',
    right_on = 'UF',
    how = 'right'
)

print(esp_df.shape)
esp_df.head()
# Out:
# (27, 21)
#   CD_UF               NM_UF SIGLA_UF     NM_REGIAO  \
# 0    53    Distrito Federal       DF  Centro-oeste
# 1    52               Goiás       GO  Centro-oeste
# 2    51         Mato Grosso       MT  Centro-oeste
# 3    50  Mato Grosso do Sul       MS  Centro-oeste
# 4    25             Paraíba       PB      Nordeste
#
#                                             geometry  UF             Nome_UF  \
# 0  POLYGON ((-47.41734 -15.54655, -47.41720 -15.5...  DF    Distrito Federal
# 1  POLYGON ((-52.36102 -16.08160, -52.36040 -16.0...  GO               Goiás
# 2  POLYGON ((-61.54023 -10.00021, -61.54014 -9.99...  MT         Mato Grosso
# 3  POLYGON ((-57.83371 -20.93628, -57.83553 -20.9...  MS  Mato Grosso do Sul
# 4  MULTIPOLYGON (((-34.79576 -7.35000, -34.79601 ...  PB             Paraíba
#
#    Densidade_populacional_projetada  IDHM 2010  Renda per capita 2010  ...  \
# 0                        530.335628      0.824                1715.11  ...
# 1                         20.907243      0.735                 810.97  ...
# 2                          3.904110      0.725                 762.52  ...
# 3                          7.866190      0.729                 799.34  ...
# 4                         71.533102      0.658                 474.94  ...
#
#    casosAcumulado_12  Valor_compra_var  Valor_contratado_var  \
# 0             251701           -402.04          4.000893e+08
# 1             308868         -30000.00          3.685401e+08
# 2             179427          15000.00          1.600231e+08
# 3             133761          -5000.00          1.237608e+08
# 4             166484         -28540.50          1.021812e+08
#
#    Taxa_prop_media_var  Area_privativa_var  População_estimada  \
# 0            -0.401995               -1.39             3055149
# 1            -0.398489               -6.50             7113540
# 2            -0.343558               -0.78             3526220
# 3            -0.056017               -7.78             2809394
# 4            -0.730176               -8.35             4039277
#
#    SDO_emprego pela pop_estim  Val_compr pela pop_estim  \
# 0                   -0.000812                 -0.000132
# 1                   -0.001306                 -0.004217
# 2                   -0.003942                  0.004254
# 3                   -0.001538                 -0.001780
# 4                    0.000919                 -0.007066
#
#    Val_contr pela pop_estim  SdoEmpresas_var
# 0                130.955752          29921.0
# 1                 51.808258          60071.0
# 2                 45.380904          30849.0
# 3                 44.052476          23441.0
# 4                 25.296902          21000.0
#
# [5 rows x 21 columns]

# %%
esp_df.to_file('Shapefiles/Estado-Var')

# %% [markdown]
# ### Selecionar dados para modelos

# %%
target = 'Valor_compra_var'

x = df.iloc[:,2:].drop([target], axis = 1)

labels = x.columns

y = df[target]

x_y = pd.merge(x, y, left_index=True, right_index=True)

x.head()
# Out:
#        Densidade_populacional_projetada  IDHM 2010  Renda per capita 2010  \
# CD_UF
# 53                           530.335628      0.824                1715.11
# 52                            20.907243      0.735                 810.97
# 51                             3.904110      0.725                 762.52
# 50                             7.866190      0.729                 799.34
# 25                            71.533102      0.658                 474.94
#
#        SaldoEmprego_var  casosAcumulado_12  Valor_contratado_var  \
# CD_UF
# 53              -2480.0             251701          4.000893e+08
# 52              -9289.0             308868          3.685401e+08
# 51             -13899.0             179427          1.600231e+08
# 50              -4320.0             133761          1.237608e+08
# 25               3712.0             166484          1.021812e+08
#
#        Taxa_prop_media_var  Area_privativa_var  População_estimada  \
# CD_UF
# 53               -0.401995               -1.39             3055149
# 52               -0.398489               -6.50             7113540
# 51               -0.343558               -0.78             3526220
# 50               -0.056017               -7.78             2809394
# 25               -0.730176               -8.35             4039277
#
#        SDO_emprego pela pop_estim  Val_compr pela pop_estim  \
# CD_UF
# 53                      -0.000812                 -0.000132
# 52                      -0.001306                 -0.004217
# 51                      -0.003942                  0.004254
# 50                      -0.001538                 -0.001780
# 25                       0.000919                 -0.007066
#
#        Val_contr pela pop_estim  SdoEmpresas_var
# CD_UF
# 53                   130.955752          29921.0
# 52                    51.808258          60071.0
# 51                    45.380904          30849.0
# 50                    44.052476          23441.0
# 25                    25.296902          21000.0

# %% [markdown]
# ### Correlações

# %%
scripts.corr(x_y, figsize = (20,15))

# %% [markdown]
# ### PPS index

# %%
plt.figure(figsize=(20, 15))

matrix_df = pps.matrix(x_y)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')

sns.heatmap(matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)

plt.show()

# %% [markdown]
# ### Remoção de Variáveis com alta correlação

# %%
x = x[variables_sel]

labels = x.columns

x_y = pd.merge(x, y, left_index=True, right_index=True)


x.head()
# Out:
#        Renda per capita 2010  SaldoEmprego_var  Valor_contratado_var  \
# CD_UF
# 53                   1715.11           -2480.0          4.000893e+08
# 52                    810.97           -9289.0          3.685401e+08
# 51                    762.52          -13899.0          1.600231e+08
# 50                    799.34           -4320.0          1.237608e+08
# 25                    474.94            3712.0          1.021812e+08
#
#        Area_privativa_var  População_estimada  SDO_emprego pela pop_estim  \
# CD_UF
# 53                  -1.39             3055149                   -0.000812
# 52                  -6.50             7113540                   -0.001306
# 51                  -0.78             3526220                   -0.003942
# 50                  -7.78             2809394                   -0.001538
# 25                  -8.35             4039277                    0.000919
#
#        Val_compr pela pop_estim  Val_contr pela pop_estim
# CD_UF
# 53                    -0.000132                130.955752
# 52                    -0.004217                 51.808258
# 51                     0.004254                 45.380904
# 50                    -0.001780                 44.052476
# 25                    -0.007066                 25.296902

# %%
scripts.corr(x_y, figsize = (20,15))

# %% [markdown]
# #### VIF

# %%
scripts.plot_vif(x)

# %% [markdown]
# #### Skewness e Kurtosis

# %%
scripts.plot_skew_kurtosis(x)

# %% [markdown]
# ### Realizar Normalização

# %%
x_norm = pd.DataFrame(StandardScaler().fit_transform(x), columns = x.columns, index = x.index)

x_y_norm = pd.DataFrame(StandardScaler().fit_transform(x_y), columns = x_y.columns, index = x_y.index)

# %% [markdown]
# ### Regressão Linear

# %%
lm = sm.OLS(endog = y, exog = add_constant(x_norm))

r = lm.fit()

sns.regplot(x = r.predict(add_constant(x_norm)), y = y)

plt.show()

r.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Valor_compra_var   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     21.86
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           9.09e-08
# Time:                        22:58:49   Log-Likelihood:                -290.36
# No. Observations:                  27   AIC:                             598.7
# Df Residuals:                      18   BIC:                             610.4
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       4827.0944   2669.914      1.808      0.087    -782.188    1.04e+04
# Renda per capita 2010       2.317e+04   1.05e+04      2.205      0.041    1095.419    4.52e+04
# SaldoEmprego_var             1.97e+04   1.21e+04      1.633      0.120   -5653.098    4.51e+04
# Valor_contratado_var        4.659e+04    1.6e+04      2.906      0.009    1.29e+04    8.03e+04
# Area_privativa_var          2.755e+04   3762.818      7.322      0.000    1.96e+04    3.55e+04
# População_estimada         -3.009e+04   9283.068     -3.241      0.005   -4.96e+04   -1.06e+04
# SDO_emprego pela pop_estim -1.086e+04   6623.982     -1.640      0.118   -2.48e+04    3055.234
# Val_compr pela pop_estim    9972.4240   3708.062      2.689      0.015    2182.074    1.78e+04
# Val_contr pela pop_estim   -2.662e+04   9988.770     -2.665      0.016   -4.76e+04   -5637.973
# ==============================================================================
# Omnibus:                        2.963   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                1.499
# Skew:                          -0.392   Prob(JB):                        0.473
# Kurtosis:                       3.848   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Stepwise Critério AIC

# %%
drop, aic_remaing, labels_remaining = scripts.iterate_aic(x_norm, y)

drop
# Out:
# ['Area_privativa_var', 'Val_compr pela pop_estim', 'SaldoEmprego_var']

# %% [markdown]
# #### Cross Validation

# %%
pred = scripts.out_of_fold_pred(x_norm.values, y.values, LinearRegression(), folds = 10)

m = scripts.get_metrics(prediction = pred, actual = y.values)
# Out:
# Results
# MSE: 701821774.277
# RMSE: 26491.919
# MAE: 19186.946
# R2: 0.489

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components = 2)

pca_coord = pca.fit_transform(x_y_norm)

# %% [markdown]
# ### KMeans

# %%
kmeans = KMeans(n_clusters = 2).fit_transform(x_y_norm)

sns.scatterplot(pca_coord[:,0], pca_coord[:,1], hue = kmeans.argmax(axis = 1), )
# Out:
# /Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/venv-gv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
pd.DataFrame({'Cidade': df['UF'], 'Cluster': kmeans.argmax(axis = 1)}).sort_values(by = 'Cluster')
# Out:
#       Cidade  Cluster
# CD_UF
# 35        SP        0
# 53        DF        1
# 43        RS        1
# 31        MG        1
# 32        ES        1
# 33        RJ        1
# 15        PA        1
# 16        AP        1
# 17        TO        1
# 11        RO        1
# 12        AC        1
# 13        AM        1
# 42        SC        1
# 14        RR        1
# 26        PE        1
# 27        AL        1
# 28        SE        1
# 29        BA        1
# 22        PI        1
# 23        CE        1
# 24        RN        1
# 25        PB        1
# 50        MS        1
# 51        MT        1
# 52        GO        1
# 21        MA        1
# 41        PR        1

# %% [markdown]
# ##### Outlier

# %%
df[pca_coord[:,0] > 5]
# Out:
#        UF    Nome_UF  Densidade_populacional_projetada  IDHM 2010  \
# CD_UF
# 35     SP  São Paulo                        186.485496      0.783
#
#        Renda per capita 2010  SaldoEmprego_var  casosAcumulado_12  \
# CD_UF
# 35                   1084.46          -89127.0            1462084
#
#        Valor_compra_var  Valor_contratado_var  Taxa_prop_media_var  \
# CD_UF
# 35              25000.0          3.419564e+09            -0.464764
#
#        Area_privativa_var  População_estimada  SDO_emprego pela pop_estim  \
# CD_UF
# 35                   5.97            46289333                   -0.001925
#
#        Val_compr pela pop_estim  Val_contr pela pop_estim  SdoEmpresas_var
# CD_UF
# 35                      0.00054                 73.873689         451808.0

# %% [markdown]
# Removendo Outliers

# %%
slicer = pca_coord[:,0] < 5

pca = PCA(n_components = 2)

pca_coord_new = pca.fit_transform(x_y_norm.values[slicer])

kmeans_new = KMeans(n_clusters = 2).fit_transform(x_y_norm.values[slicer])

sns.scatterplot(pca_coord_new[:,0], pca_coord_new[:,1], hue = kmeans_new.argmax(axis = 1), )

plt.show()

pd.DataFrame({'Cidade': df['UF'][slicer], 'Cluster': kmeans_new.argmax(axis = 1)}).sort_values(by = 'Cluster')
# Out:
# /Users/matheus/Documents/MBA FGV/Desafios e Requisitos dos Projetos Analíticos/venv-gv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#       Cidade  Cluster
# CD_UF
# 21        MA        0
# 11        RO        0
# 12        AC        0
# 13        AM        0
# 14        RR        0
# 33        RJ        0
# 26        PE        0
# 27        AL        0
# 17        TO        0
# 28        SE        0
# 22        PI        0
# 23        CE        0
# 24        RN        0
# 25        PB        0
# 32        ES        0
# 31        MG        0
# 29        BA        0
# 15        PA        0
# 43        RS        1
# 53        DF        1
# 42        SC        1
# 50        MS        1
# 51        MT        1
# 52        GO        1
# 16        AP        1
# 41        PR        1

# %% [markdown]
# ### Cluster Dendograma

# %%
linked = linkage(x_y_norm.values, 'ward')

plt.figure(figsize=(20, 15))
dendrogram(
            linked,
            orientation='right',
            labels=df['UF'].values,
            distance_sort='descending',
            show_leaf_counts=False
          )
plt.show()

# %% [markdown]
# ### Regressão Espacial

# %%
ax = esp_df.plot(
    column = target,
    figsize = (10,10),
    legend = True,
    legend_kwds = {'label': target, 'orientation': "horizontal"},
)

ax.set_title(target)

ax.set_axis_off()

# %%
esp_df.shape
# Out:
# (27, 21)

# %%
w = libpysal.weights.Rook.from_dataframe(esp_df, )

# w = libpysal.weights.Queen.from_dataframe(esp_df, )

w.transform = 'r'

# %%
warnings.filterwarnings('ignore', module = 'libpysal')

ax = esp_df.plot(edgecolor='grey', facecolor='w',figsize=(10,10) )

f, ax = w.plot(esp_df, ax=ax,
        edge_kws=dict(color='r', linestyle=':', linewidth=1),
        node_kws=dict(marker=''),
              )

ax.set_axis_off()

# %%
moran_I = {}
moran = {}
moran_local = {}

for i in x_y_norm.columns:
    
    moran[i] = esda.Moran(x_y_norm[i].values, w)
    moran_local[i] = esda.moran.Moran_Local(x_y_norm[i].values, w)
    moran_I[i] = moran[i].I

# %%
(pd.Series(moran_I)
     .rename('Moran I')
     .sort_values(ascending = False)
     .to_frame()
)
# Out:
#                              Moran I
# Renda per capita 2010       0.453059
# Val_contr pela pop_estim    0.368495
# SDO_emprego pela pop_estim  0.326726
# Valor_contratado_var        0.220787
# Valor_compra_var            0.219076
# População_estimada          0.192211
# Val_compr pela pop_estim    0.152466
# SaldoEmprego_var            0.132116
# Area_privativa_var          0.022567

# %%
n = 4

for i in sorted(moran_I.items(), key=lambda x: x[1], reverse=True)[:n]:
    print(i[0])
    moran_scatterplot(moran[i[0]], aspect_equal=True)
    plt.show()
# Out:
# Renda per capita 2010
# Val_contr pela pop_estim
# SDO_emprego pela pop_estim
# Valor_contratado_var

# %%
n = 4

for i in sorted(moran_I.items(), key=lambda x: x[1], reverse=True)[:n]:
    print(i[0])

    fig, ax = lisa_cluster(moran_local[i[0]], esp_df, p=0.05, figsize = (9,9))
    ax.set_title(i[0])
    plt.show()
# Out:
# Renda per capita 2010
# Val_contr pela pop_estim
# SDO_emprego pela pop_estim
# Valor_contratado_var

# %%
r = spreg.OLS(
        x = x_norm.values, name_x = list(labels),
        y = y.values, 
        w = w,
    )

print(r.summary)

sns.regplot(x = r.predy, y = y)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :     dep_var                Number of Observations:          27
# Mean dependent var  :   4827.0944                Number of Variables   :           9
# S.D. dependent var  :  37783.8084                Degrees of Freedom    :          18
# R-squared           :      0.9067
# Adjusted R-squared  :      0.8652
# Sum squared residual:3464423318.398                F-statistic           :     21.8566
# Sigma-square        :192467962.133                Prob(F-statistic)     :   9.091e-08
# S.E. of regression  :   13873.282                Log likelihood        :    -290.356
# Sigma-square ML     :128311974.755                Akaike info criterion :     598.712
# S.E of regression ML:  11327.4876                Schwarz criterion     :     610.375
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    4827.0944444    2669.9144260       1.8079585       0.0873529
# Renda per capita 2010    23167.2593082    10505.7875352       2.2051902       0.0406854
#     SaldoEmprego_var    19702.5011988    12068.7959058       1.6325159       0.1199412
# Valor_contratado_var    46587.5904738    16029.6004634       2.9063476       0.0094154
#   Area_privativa_var    27552.4392510    3762.8178668       7.3222888       0.0000008
#   População_estimada    -30090.8329897    9283.0677942      -3.2414751       0.0045297
# SDO_emprego pela pop_estim    -10861.2362108    6623.9823055      -1.6396838       0.1184301
# Val_compr pela pop_estim    9972.4239757    3708.0623664       2.6893895       0.0149854
# Val_contr pela pop_estim    -26623.6001604    9988.7699490      -2.6653532       0.0157685
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           15.262
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2           1.499           0.4727
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                8          11.677           0.1662
# Koenker-Bassett test              8           8.201           0.4141
# ================================ END OF REPORT =====================================
# <AxesSubplot:ylabel='Valor_compra_var'>

# %%
spatial_regression = spreg.GM_Lag(
        x = x_norm.values, name_x = list(labels),
        y = y.values, name_y = 'preco',
        w = w,
    
        
    )

print(
    spatial_regression.summary
)

sns.regplot(x = spatial_regression.predy, y = y)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: SPATIAL TWO STAGE LEAST SQUARES
# --------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :       preco                Number of Observations:          27
# Mean dependent var  :   4827.0944                Number of Variables   :          10
# S.D. dependent var  :  37783.8084                Degrees of Freedom    :          17
# Pseudo R-squared    :      0.9056
# Spatial Pseudo R-squared:  0.9073
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT    4229.8911781    2477.9747451       1.7069953       0.0878229
# Renda per capita 2010    21118.0327036    9493.4701439       2.2244798       0.0261162
#     SaldoEmprego_var    19473.1479954    9920.1975364       1.9629799       0.0496485
# Valor_contratado_var    44674.1242031    13672.9125172       3.2673451       0.0010856
#   Area_privativa_var    28015.5095398    3216.9830700       8.7086282       0.0000000
#   População_estimada    -28527.6073826    8200.3215041      -3.4788401       0.0005036
# SDO_emprego pela pop_estim    -10572.8097993    5467.7981766      -1.9336503       0.0531561
# Val_compr pela pop_estim    8783.6916338    3815.1914634       2.3022938       0.0213186
# Val_contr pela pop_estim    -23826.8336611    9824.8858863      -2.4251512       0.0153020
#              W_preco       0.0658553       0.1273522       0.5171117       0.6050782
# ------------------------------------------------------------------------------------
# Instrumented: W_preco
# Instruments: W_Area_privativa_var, W_População_estimada, W_Renda per capita
#              2010, W_SDO_emprego pela pop_estim, W_SaldoEmprego_var,
#              W_Val_compr pela pop_estim, W_Val_contr pela pop_estim,
#              W_Valor_contratado_var
# ================================ END OF REPORT =====================================
# <AxesSubplot:ylabel='Valor_compra_var'>

# %% [markdown]
# ### Random Forests

# %%
rf = RandomForestRegressor(n_estimators = 200)

rf.fit(y = y, X = x_norm)
# Out:
# RandomForestRegressor(n_estimators=200)

# %%
pd.Series(rf.feature_importances_, index = labels).sort_values().plot.barh(figsize = (10,10))

plt.show()

# %%
sns.regplot(x = rf.predict(x_norm), y = y)

plt.show()

# %%
pred = scripts.out_of_fold_pred(x_norm.values, y.values, RandomForestRegressor(n_estimators = 50), folds = 10)

m = scripts.get_metrics(prediction = pred, actual = y.values)
# Out:
# Results
# MSE: 749549686.360
# RMSE: 27377.905
# MAE: 15353.023
# R2: 0.455

# %% [markdown]
# #### Recursive Feature Eliminations

# %%
selector_rf = RFE(rf, n_features_to_select=.5, step=1)

selector_rf = selector_rf.fit(x_norm.values, y.values)

print('Best Features')
pd.Series(selector_rf.ranking_, index = labels).sort_values()
# Out:
# Best Features
# Densidade_populacional_projetada    1
# SaldoEmprego_var                    1
# Valor_contratado_var                1
# Area_privativa_var                  1
# Val_compr pela pop_estim            1
# SdoEmpresas_var                     1
# Val_contr pela pop_estim            2
# casosAcumulado_12                   3
# Taxa_prop_media_var                 4
# IDHM 2010                           5
# Renda per capita 2010               6
# População_estimada                  7
# SDO_emprego pela pop_estim          8
# dtype: int64

# %% [markdown]
# ### Linear Support Vector Regression

# %%
svr = SVR(kernel = 'linear')

svr = svr.fit(y = y, X = x_norm)

# %%
sns.regplot(x = svr.predict(x_norm), y = y)

plt.show()

# %%
pred = scripts.out_of_fold_pred(x_norm.values, y.values, svr, folds = 10)

m = scripts.get_metrics(prediction = pred, actual = y.values)
# Out:
# Results
# MSE: 1479947109.259
# RMSE: 38470.081
# MAE: 24077.907
# R2: -0.077

# %%
selector_svr = RFE(SVR(kernel='linear'), n_features_to_select=.5, step=1)

selector_svr = selector_svr.fit(x_norm.values, y.values)

print('Best Features')
pd.Series(selector_svr.ranking_, index = labels).sort_values()
# Out:
# Best Features
# IDHM 2010                           1
# Renda per capita 2010               1
# Area_privativa_var                  1
# SDO_emprego pela pop_estim          1
# Val_compr pela pop_estim            1
# SdoEmpresas_var                     1
# SaldoEmprego_var                    2
# casosAcumulado_12                   3
# Valor_contratado_var                4
# População_estimada                  5
# Taxa_prop_media_var                 6
# Val_contr pela pop_estim            7
# Densidade_populacional_projetada    8
# dtype: int64

# %%
pd.DataFrame(
    {
    'RF Feature Importance': np.argsort(-rf.feature_importances_),
    'RF RFE': selector_rf.ranking_,
    'SVR RFE': selector_svr.ranking_
},
    index = labels
)
# Out:
#                                   RF Feature Importance  RF RFE  SVR RFE
# Densidade_populacional_projetada                     10       1        8
# IDHM 2010                                             7       5        1
# Renda per capita 2010                                 0       6        1
# SaldoEmprego_var                                      8       1        2
# casosAcumulado_12                                     5       3        3
# Valor_contratado_var                                 12       1        4
# Taxa_prop_media_var                                   4       4        6
# Area_privativa_var                                   11       1        1
# População_estimada                                    6       7        5
# SDO_emprego pela pop_estim                            1       8        1
# Val_compr pela pop_estim                              3       1        1
# Val_contr pela pop_estim                              9       2        7
# SdoEmpresas_var                                       2       1        1
